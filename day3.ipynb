# %%
print(3*2)
# Out:
# 6

# %%
print(1//3)
# Out:
# 0

# %%
print(5//6)
# Out:
# 0

# %%
print(1%3)
# Out:
# 1

# %%
print(3**1/2)
# Out:
# 1.5

# %%
print(9**1/2)
# Out:
# 4.5

# %%
print(9**0.5)
# Out:
# 3.0

# %%
print(3**0.5)
# Out:
# 1.7320508075688772

# %%
a=2

# %%
print(a+=1)
# Out:
#   Cell In[10], line 1
#     print(a+=1)
#            ^
# SyntaxError: invalid syntax

# %%
a+=1

# %%
print(a)
# Out:
# 3

# %%
num1=99 #chengben

# %%
num2=66 #lirun

# %%
num3=num1+num2 #shoujia

# %%
print(num3)
# Out:
# 165

# %%
num1+=num2

# %%
print(num1)
# Out:
# 165

# %%
num1 -=num2

# %%
print(num1)
# Out:
# 99

# %%
input("password")

# %%
panpeiyuan

# %%
a=input()

# %%
3

# %%
b=input()
3

# %%
print(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(b)
#
# NameError: name 'b' is not defined

# %%
import numpy as np

# %%
i=np.array([1,0])

# %%
j=np.array([0,1])

# %%
print(3*i+2*j)
# Out:
# [3 2]

# %%
M=np.array([1,2],[2,2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 M=np.array([1,2],[2,2])
#
# TypeError: Field elements must be 2- or 3-tuples, got '2'

# %%
M=np.array([[1,2],[2,2]])

# %%
N=np.array([3,4],[5,6])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 N=np.array([3,4],[5,6])
#
# TypeError: Field elements must be 2- or 3-tuples, got '5'

# %%
N=np.array([[3,4],[5,6]])

# %%
print(np.linalg.solve(m,[5,1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(np.linalg.solve(m,[5,1]))
#
# NameError: name 'm' is not defined

# %%
print(np.linalg.solve(M,[5,1]))
# Out:
# [-4.   4.5]

# %%
print(np.linalg.solve(N,[5,1]))
# Out:
# [-13.  11.]

# %%
print(np.linalg.solve([5,1],M))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File d:\Anaconda3\Lib\site-packages\numpy\linalg\_linalg.py:240, in _assert_stacked_square(*arrays)
#     239 try:
# --> 240     m, n = a.shape[-2:]
#     241 except ValueError:
#
# ValueError: not enough values to unpack (expected 2, got 1)
#
# During handling of the above exception, another exception occurred:
#
# LinAlgError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 print(np.linalg.solve([5,1],M))
#
# File d:\Anaconda3\Lib\site-packages\numpy\linalg\_linalg.py:437, in solve(a, b)
#     364 """
#     365 Solve a linear matrix equation, or system of linear scalar equations.
#     366
#    (...)    434
#     435 """
#     436 a, _ = _makearray(a)
# --> 437 _assert_stacked_square(a)
#     438 b, wrap = _makearray(b)
#     439 t, result_t = _commonType(a, b)
#
# ...

# %%
w=2

# %%
b=1

# %%
x=np.array([1,2,3,4,5])

# %%
y=w*x+b

# %%
print(y)
# Out:
# [ 3  5  7  9 11]

# %%
rng=np.random.default_rng(0)

# %%
X=rng.normal(size=(10,2))

# %%
print(X)
# Out:
# [[ 0.12573022 -0.13210486]
#  [ 0.64042265  0.10490012]
#  [-0.53566937  0.36159505]
#  [ 1.30400005  0.94708096]
#  [-0.70373524 -1.26542147]
#  [-0.62327446  0.04132598]
#  [-2.32503077 -0.21879166]
#  [-1.24591095 -0.73226735]
#  [-0.54425898 -0.31630016]
#  [ 0.41163054  1.04251337]]

# %%
print("""\
Usage:thingy [OPTIONS]
        -H
    """)
# Out:
# Usage:thingy [OPTIONS]
#         -H

# %%
'oy''ok'
# Out:
# 'oyok'

# %%
word='py'

# %%
word[-3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 word[-3]
#
# IndexError: string index out of range

# %%
word[-1]
# Out:
# 'y'

# %%
word.replace('p','j')
# Out:
# 'jy'

# %%
cubes=[1,2,3,4]

# %%
cubes+4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 cubes+4
#
# TypeError: can only concatenate list (not "int") to list

# %%
cubes+[4]
# Out:
# [1, 2, 3, 4, 4]

# %%
cubes[0]
# Out:
# 1

# %%
cubes.append[1,2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 cubes.append[1,2]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
cubes.append(111)

# %%
cubes
# Out:
# [1, 2, 3, 4, 111]

# %%
cubes.append([1,2])

# %%
cubes
# Out:
# [1, 2, 3, 4, 111, [1, 2]]

# %%
cubes.append(1,2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 cubes.append(1,2,3)
#
# TypeError: list.append() takes exactly one argument (3 given)

# %%
a=[1,2]

# %%
id(a)
# Out:
# 2695682853824

# %%
b=[1,2]

# %%
id(b)
# Out:
# 2695682853632

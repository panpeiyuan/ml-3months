# %%
a=2

# %%
a**(1/2)
# Out:
# 1.4142135623730951

# %%
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
b=4

# %%
a=b

# %%
if a=b
# Out:
#   Cell In[6], line 1
#     if a=b
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
a=[1,2,3,4]

# %%
b=a

# %%
a
# Out:
# [1, 2, 3, 4]

# %%
b
# Out:
# [1, 2, 3, 4]

# %%
b=a[:]]
# Out:
#   Cell In[11], line 1
#     b=a[:]]
#           ^
# SyntaxError: unmatched ']'

# %%
a is b
# Out:
# True

# %%
a is not b
# Out:
# False

# %%
del a

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
a=1

# %%
a=a+1

# %%
a
# Out:
# 2

# %%
a+=1

# %%
a
# Out:
# 3

# %%
if a != b
print("yes")
# Out:
#   Cell In[21], line 1
#     if a != b
#              ^
# SyntaxError: expected ':'

# %%
if a==b{
    print("yes")
}
# Out:
#   Cell In[22], line 1
#     if a==b{
#            ^
# SyntaxError: invalid syntax

# %%
if a==b:
    print(1)

# %%
if a!=b :
    print(1)
# Out:
# 1

# %%
a!=b
# Out:
# True

# %%
b="sq"

# %%
a=1

# %%
c=a+int(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 c=a+int(b)
#
# ValueError: invalid literal for int() with base 10: 'sq'

# %%
help(sys)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 help(sys)
#
# NameError: name 'sys' is not defined

# %%
import sys

# %%
help(sys)
# Out:
# Help on built-in module sys:
#
# NAME
#     sys
#
# MODULE REFERENCE
#     https://docs.python.org/3.14/library/sys#module-sys
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This module provides access to some objects used or maintained by the
#     interpreter and to functions that interact strongly with the interpreter.
#
#     Dynamic objects:
#
#     argv -- command line arguments; argv[0] is the script pathname if known
#     path -- module search path; path[0] is the script directory, else ''
#     modules -- dictionary of loaded modules
#
#     displayhook -- called to show results in an interactive session
# ...

# %%
help(abs)
# Out:
# Help on built-in function abs in module builtins:
#
# abs(x, /)
#     Return the absolute value of the argument.

# %%
import numpy as np

# %%
A=np.array([[1,2],[3,4]])
B=np.array([[5,6],[7,8]])

# %%
print(A@B)
# Out:
# [[19 22]
#  [43 50]]

# %%
print(A.T)
# Out:
# [[1 3]
#  [2 4]]

# %%
print(np.linalg.det(A))
# Out:
# -2.0000000000000004

# %%
print(np.linalg.inv(A))
# Out:
# [[-2.   1. ]
#  [ 1.5 -0.5]]

# %%
print(np.linalg.matrix_rank(A))
# Out:
# 2

# %%
print(np.linalg.slove(A,[5,11]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 print(np.linalg.slove(A,[5,11]))
#
# AttributeError: module 'numpy.linalg' has no attribute 'slove'

# %%
print(np.linalg.solve[A,[5,11]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 print(np.linalg.solve[A,[5,11]])
#
# TypeError: 'numpy._ArrayFunctionDispatcher' object is not subscriptable

# %%
print(np.linalg.solve(A,[5,11]))
# Out:
# [1. 2.]

# %%
print(np.linalg.eig(A))
# Out:
# EigResult(eigenvalues=array([-0.37228132,  5.37228132]), eigenvectors=array([[-0.82456484, -0.41597356],
#        [ 0.56576746, -0.90937671]]))

# %%
name=str(panpeiyuan)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 name=str(panpeiyuan)
#
# NameError: name 'panpeiyuan' is not defined

# %%
name="panpeiyuan"

# %%
age=22

# %%
high=1.82

# %%
print(name,age,high)
# Out:
# panpeiyuan 22 1.82

# %%
print(type(name),type(age)，type(high))
# Out:
#   Cell In[50], line 1
#     print(type(name),type(age)，type(high))
#                               ^
# SyntaxError: invalid character '，' (U+FF0C)

# %%
print(type(name,age,high))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 print(type(name,age,high))
#
# TypeError: type.__new__() argument 2 must be tuple, not int

# %%
print(type(name) type(age) type(high))
# Out:
#   Cell In[52], line 1
#     print(type(name) type(age) type(high))
#                      ^
# SyntaxError: invalid syntax

# %%
type(name)
# Out:
# str

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(name),type(age),type(high))
# Out:
# <class 'str'> <class 'int'> <class 'float'>

# %%
s='Hello,Python'

# %%
len(s)
# Out:
# 12

# %%
s='Hello, world'

# %%
len(s)
# Out:
# 12

# %%
upper(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 upper(s)
#
# NameError: name 'upper' is not defined

# %%
print(upper(s))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 print(upper(s))
#
# NameError: name 'upper' is not defined

# %%
print(s.upper())
# Out:
# HELLO, WORLD

# %%
name=pan
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 name=pan
#
# NameError: name 'pan' is not defined

# %%
name="pan"

# %%
print("名字:",name)
# Out:
# 名字: pan

# %%
print("名字:%s"%name)
# Out:
# 名字:pan

# %%
age=22

# %%
print("名字：%s,年龄：%d"%(name,age))
# Out:
# 名字：pan,年龄：22

# %%
print("名字：%4s"%name)
# Out:
# 名字： pan

# %%
print("名字：%06s"%name)
# Out:
# 名字：   pan

# %%
print("名字：%07s"%name)
# Out:
# 名字：    pan

# %%
print("nianling:%07d"%age)
# Out:
# nianling:0000022

# %%
print(s.lower())
# Out:
# hello, world

# %%
print(s.replace('Python','panpeiyuan'))
# Out:
# Hello, world

# %%
print(s.replace('world','panpeiyuan'))
# Out:
# Hello, panpeiyuan

# %%
score=[88,98,97,77,87,81,79,63,95,54]

# %%
population=count(score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 population=count(score)
#
# NameError: name 'count' is not defined

# %%
population=score.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 population=score.count()
#
# TypeError: list.count() takes exactly one argument (0 given)

# %%
len.score
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 len.score
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'score'

# %%
score.len()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 score.len()
#
# AttributeError: 'list' object has no attribute 'len'

# %%
len(score)
# Out:
# 10

# %%
score=[88, 92, 79, 95, 60, 73, 100, 45, 81, 67]

# %%
sum(score)
# Out:
# 780
